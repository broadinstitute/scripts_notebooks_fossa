# %% [markdown]
# # Select cells from database
#
# This notebook is intended to retrieve single-cells from a database file.
#
# Requirements:
# - Nuclei, Cells and Cytoplasm objects named in that way;
# - Output database .db file from ExportToDatabase (CellProfiler);
# - Each database file is named after the Metadata_Plate name, e.g. 220607_092050_Plate_1;
#     - Provide a plate_list with all plate names: `plate_list = ['plate1', 'plate2', ...]`
# - All databased files must be organized such:
#     ```
#     |- backend
#     |   |- <project_name>
#     |   |   |- <plate_name>
#     |   |   |   |- <plate1.db>
#     |   |   |- <plate_name>
#     |   |   |   |- <plate2.db>
#     ...
#     ```

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from functools import reduce
from sklearn.cluster import KMeans
from openpyxl import Workbook, load_workbook
import os
import easygui as eg
from numpy import random
import sqlite3
import pycytominer
from pycytominer.cyto_utils.cells import SingleCells

# %% [markdown]
# ## Import database file

# %% [markdown]
# ### Import every plate and then join them

# %%
plate_list = ['220607_092050_Plate_1', '220608_152238_Plate_1', '220617_090443_Plate_1']

# %% [markdown]
# - Common path will be sqlite:/// + the location of the directory on your computer (until <project_name>)

# %%
common_path = f"sqlite:///D:/2022_09_09_LiveCellPainting_fossa_Cimini/workspace/backend/2022_06_07_DILI/"

# %% [markdown]
# - Run the next cell, and wait. This could take a long time (10 minutes or more) depending on the size of the database file.

# %%
df_list = []
for plate in plate_list:
    database = SingleCells(common_path + plate + "/" + plate + ".sqlite")
    df_temp = database.merge_single_cells()
    df_list.append(df_temp)

# %% [markdown]
# - The next cell will join the plates into a single file containing single-cell information.

# %%
df = pd.concat(df_list, axis='index')

# %%
df.head()
# Out:
#    Metadata_ImageNumber         Metadata_Plate  Metadata_Site Metadata_Well  \
# 0                     1  220607_092050_Plate_1              1           B10
# 1                     1  220607_092050_Plate_1              1           B10
# 2                     1  220607_092050_Plate_1              1           B10
# 3                     1  220607_092050_Plate_1              1           B10
# 4                     1  220607_092050_Plate_1              1           B10
#
#    Metadata_TableNumber  Metadata_ObjectNumber_cytoplasm  \
# 0            1571898871                                1
# 1            1571898871                                2
# 2            1571898871                                3
# 3            1571898871                                4
# 4            1571898871                                5
#
#    Cytoplasm_AreaShape_Area  Cytoplasm_AreaShape_BoundingBoxArea  \
# 0                     17563                                28700
# 1                     26625                                47064
# 2                     10090                                20703
# 3                     20770                                39366
# 4                     27108                                59052
#
#    Cytoplasm_AreaShape_BoundingBoxMaximum_X  \
# 0                                      1057
# 1                                       544
# 2                                       722
# 3                                      1068
# 4                                       409
#
#    Cytoplasm_AreaShape_BoundingBoxMaximum_Y  ...  \
# 0                                       195  ...
# 1                                       307  ...
# 2                                       285  ...
# 3                                       353  ...
# 4                                       405  ...
#
#    Nuclei_Texture_Variance_CorrPI_10_02_256  \
# 0                                 23.387480
# 1                                 27.535579
# 2                                190.739156
# 3                                 30.832619
# 4                                111.594226
#
#    Nuclei_Texture_Variance_CorrPI_10_03_256  \
# 0                                 23.456552
# 1                                 28.164301
# 2                                184.776425
# 3                                 32.460216
# 4                                111.980760
#
#    Nuclei_Texture_Variance_CorrPI_20_00_256  \
# 0                                 24.893570
# 1                                 29.948233
# 2                                193.994949
# 3                                 30.510909
# 4                                116.428891
#
#    Nuclei_Texture_Variance_CorrPI_20_01_256  \
# 0                                 21.909327
# 1                                 32.728835
# 2                                288.495965
# 3                                 30.444835
# 4                                115.604023
#
#    Nuclei_Texture_Variance_CorrPI_20_02_256  \
# 0                                 25.605559
# 1                                 29.760620
# 2                                229.479026
# 3                                 31.034468
# 4                                116.062754
#
#    Nuclei_Texture_Variance_CorrPI_20_03_256  \
# 0                                 26.443746
# 1                                 28.631319
# 2                                227.778470
# 3                                 29.681880
# 4                                119.931474
#
#    Nuclei_Texture_Variance_CorrPI_5_00_256  \
# 0                                23.180844
# 1                                26.867608
# 2                               226.038468
# 3                                31.185042
# 4                               115.106248
#
#    Nuclei_Texture_Variance_CorrPI_5_01_256  \
# 0                                23.307391
# 1                                27.496918
# 2                               191.521848
# 3                                31.649853
# 4                               109.352773
#
#    Nuclei_Texture_Variance_CorrPI_5_02_256  \
# 0                                22.693203
# 1                                26.937428
# 2                               187.765931
# 3                                30.655306
# 4                               108.304546
#
#    Nuclei_Texture_Variance_CorrPI_5_03_256
# 0                                22.563807
# 1                                27.227470
# 2                               190.227640
# 3                                30.647967
# 4                               108.767129
#
# [5 rows x 1817 columns]

# %%
df.tail()
# Out:
#        Metadata_ImageNumber         Metadata_Plate  Metadata_Site  \
# 50731                  1500  220617_090443_Plate_1              9
# 50732                  1500  220617_090443_Plate_1              9
# 50733                  1500  220617_090443_Plate_1              9
# 50734                  1500  220617_090443_Plate_1              9
# 50735                  1500  220617_090443_Plate_1              9
#
#       Metadata_Well  Metadata_TableNumber  Metadata_ObjectNumber_cytoplasm  \
# 50731            G9            1328917141                               38
# 50732            G9            1328917141                               39
# 50733            G9            1328917141                               40
# 50734            G9            1328917141                               41
# 50735            G9            1328917141                               42
#
#        Cytoplasm_AreaShape_Area  Cytoplasm_AreaShape_BoundingBoxArea  \
# 50731                      5224                                13624
# 50732                     17801                                41067
# 50733                     10583                                22010
# 50734                      9918                                23562
# 50735                     11126                                24603
#
#        Cytoplasm_AreaShape_BoundingBoxMaximum_X  \
# 50731                                       135
# 50732                                       625
# 50733                                       846
# 50734                                      1149
# 50735                                       761
#
#        Cytoplasm_AreaShape_BoundingBoxMaximum_Y  ...  \
# 50731                                       725  ...
# 50732                                       800  ...
# 50733                                       813  ...
# 50734                                       790  ...
# 50735                                       858  ...
#
#        Nuclei_Texture_Variance_CorrPI_10_02_256  \
# 50731                                 38.409776
# 50732                                 45.798824
# 50733                                 29.725966
# 50734                                 82.840688
# 50735                                 57.551067
#
#        Nuclei_Texture_Variance_CorrPI_10_03_256  \
# 50731                                 48.572318
# 50732                                 48.543215
# 50733                                 30.038200
# 50734                                 84.015090
# 50735                                 56.973819
#
#        Nuclei_Texture_Variance_CorrPI_20_00_256  \
# 50731                                 39.223358
# 50732                                 48.957625
# 50733                                 31.356563
# 50734                                 96.092937
# 50735                                 78.305462
#
#        Nuclei_Texture_Variance_CorrPI_20_01_256  \
# 50731                                 48.563899
# 50732                                 49.137564
# 50733                                 34.854567
# 50734                                108.861319
# 50735                                101.579515
#
#        Nuclei_Texture_Variance_CorrPI_20_02_256  \
# 50731                                 35.771190
# 50732                                 52.250616
# 50733                                 30.902707
# 50734                                 96.301985
# 50735                                 63.712774
#
#        Nuclei_Texture_Variance_CorrPI_20_03_256  \
# 50731                                 18.207022
# 50732                                 57.022030
# 50733                                 23.660524
# 50734                                 50.730780
# 50735                                 33.791654
#
#        Nuclei_Texture_Variance_CorrPI_5_00_256  \
# 50731                                39.073237
# 50732                                44.592727
# 50733                                28.144433
# 50734                                79.653462
# 50735                                56.287266
#
#        Nuclei_Texture_Variance_CorrPI_5_01_256  \
# 50731                                36.437932
# 50732                                48.394613
# 50733                                28.029887
# 50734                                80.546822
# 50735                                57.138796
#
#        Nuclei_Texture_Variance_CorrPI_5_02_256  \
# 50731                                41.391098
# 50732                                44.837983
# 50733                                28.001454
# 50734                                80.050448
# 50735                                57.691115
#
#        Nuclei_Texture_Variance_CorrPI_5_03_256
# 50731                                43.175009
# 50732                                44.014224
# 50733                                29.398238
# 50734                                90.831335
# 50735                                72.876791
#
# [5 rows x 1817 columns]

# %% [markdown]
# # Export

# %%
output_path = eg.diropenbox(msg="Choose an output folder", default=r"D:")
print('Path to save the single cell file', output_path)
project_name = input('Provide project name: ')
# Out:
# Path to save the profile D:\2022_09_09_LiveCellPainting_fossa_Cimini\workspace\profiles\2022_06_07_DILI

# %%
df.to_csv(output_path + r'/' + project_name + 'single_cells.csv')
print('Successfully exported to:', output_path + r'/' + project_name + 'single_cells.csv')
# Out:
# Successfully exported to: D:\2022_09_09_LiveCellPainting_fossa_Cimini\workspace\profiles\2022_06_07_DILI/2022_06_07_DILI_normalized_negcon_feature_select.csv

# %% [markdown]
# # Stop
#
# I have stopped here because my files are not that big, so my laptop can handle using pycytominer to this operation.
#
# If you have bigger database files and want to retrive specific images/wells, use the code below for that.

# %% [markdown]
# ## Retrieve specific wells

# %%
conn = sqlite3.connect(r"D:\2022_09_09_LiveCellPainting_fossa_Cimini\workspace\backend\2021_10_08_AgNPViability\211020_085918_Plate_1\211020_085918_Plate_1.sqlite")

# %%
well_name = ["B2", "B10"]

channels = ["CorrGFP", "CorrPI"]

# %% [markdown]
# ## Retrieve image numbers from well's names

# %%
res = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
for name in res.fetchall():
    print(name[0])
# Out:
# Image
# Nuclei
# Object relationships
# Cytoplasm
# Nucleoli
# Vesicles
# Cells

# %%
#get the names of each well as a list from well_name
rand_img_num=well_name.copy()

list_str="('"
for i in rand_img_num:
    list_str=list_str+str(i)+"','" 
list_str=list_str[:-2]+")"

print(list_str)
# Out:
# ('B2','B10')

# %%
#define the name of the well
meta_well_col_str="Image_Metadata_Well"

# %%
#create a query with the compartment names to be able to retrieve them from the table
compartment_query = "select * from {} WHERE {} IN {};".\
format("Image",meta_well_col_str,list_str)

# %%
#select the metadata and image measurements from the Image table belonging to the wells you want
plateImageDf = pd.read_sql(sql=compartment_query, con=conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\fossa\Anaconda3\envs\pycytominer\lib\site-packages\pandas\io\sql.py:2020, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2019 try:
# -> 2020     cur.execute(*args, **kwargs)
#    2021     return cur
#
# OperationalError: no such column: Image_Metadata_Well
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# g:\My Drive\Analysis\AgNP_Viability\notebooks\plot_repr_images\1_Samples_retrieval.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Analysis/AgNP_Viability/notebooks/plot_repr_images/1_Samples_retrieval.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> #select the metadata and image measurements from the Image table belonging to the wells you want
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/Analysis/AgNP_Viability/notebooks/plot_repr_images/1_Samples_retrieval.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> plateImageDf = pd.read_sql(sql=compartment_query, con=conn)
#
# File c:\Users\fossa\Anaconda3\envs\pycytominer\lib\site-packages\pandas\io\sql.py:566, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     563 pandas_sql = pandasSQL_builder(con)
#     565 if isinstance(pandas_sql, SQLiteDatabase):
# --> 566     return pandas_sql.read_query(
#     567         sql,
#     568         index_col=index_col,
#     569         params=params,
#     570         coerce_float=coerce_float,
#     571         parse_dates=parse_dates,
#     572         chunksize=chunksize,
#     573     )
#     575 try:
#     576     _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\fossa\Anaconda3\envs\pycytominer\lib\site-packages\pandas\io\sql.py:2080, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2068 def read_query(
#    2069     self,
#    2070     sql,
#    (...)
#    2076     dtype: DtypeArg | None = None,
#    2077 ):
#    2079     args = _convert_params(sql, params)
# -> 2080     cursor = self.execute(*args)
#    2081     columns = [col_desc[0] for col_desc in cursor.description]
#    2083     if chunksize is not None:
#
# File c:\Users\fossa\Anaconda3\envs\pycytominer\lib\site-packages\pandas\io\sql.py:2032, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2029     raise ex from inner_exc
#    2031 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2032 raise ex from exc
#
# DatabaseError: Execution failed on sql 'select * from Image WHERE Image_Metadata_Well IN ('B2','B10');': no such column: Image_Metadata_Well

# %%
#get the ImageNumbers for the wells you want
img_nums=plateImageDf.ImageNumber.unique().tolist()

list_str2="("
for i in img_nums:
    list_str2=list_str2+str(i)+',' 
list_str2=list_str2[:-1]+")"

print(list_str2)
# Out:
# (10,11,12,13,14,15,16,17,18,55,56,57,58,59,60,61,62,63,271,272,273,274,275,276,277,278,279,810,811,812,813,814,815,816,817,818,828,829,830,831,832,833,834,835,836,1620,1621,1622,1623,1624,1625,1626,1627,1628,2106,2107,2108,2109,2110,2111,2112,2113,2114,2538,2539,2540,2541,2542,2543,2544,2545,2546)

# %%
#from the compartment names, open each table and retrieve information from the images on list_str2
plateDf_list=[]
compartments=["cells", "cytoplasm", "nuclei"]

for compartment in compartments:
    compartment_query = "select * from {} WHERE {} IN {};".format(compartment,"ImageNumber",list_str2)
    plateDf_list.append(pd.read_sql(sql=compartment_query, con=conn))

# %%
#create the dataframe from the Df_list 
plateDf = reduce(lambda left,right: pd.merge(left,right,on=["TableNumber", "ImageNumber", "ObjectNumber"]), plateDf_list)

# %%
#merge information from Image table with cells data
plateDfwMeta = pd.merge(plateDf, plateImageDf, on=["TableNumber", "ImageNumber"])

# %%
#exclude duplicated cols
plateDfwMeta = plateDfwMeta.loc[:,~plateDfwMeta.columns.duplicated()]

# %%
#create a copy
df_p_s0 = plateDfwMeta

# %%
#take a look at the dataframe
print(df_p_s0.shape)
df_p_s0.head()
# Out:
# (7577, 2442)
#                         TableNumber  ImageNumber  ObjectNumber  \
# 0  1240fc906b760746bfaa4913fdb947b6           10             1
# 1  1240fc906b760746bfaa4913fdb947b6           10             2
# 2  1240fc906b760746bfaa4913fdb947b6           10             3
# 3  1240fc906b760746bfaa4913fdb947b6           10             4
# 4  1240fc906b760746bfaa4913fdb947b6           10             5
#
#    Cells_AreaShape_Area  Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                  7334                     642.0                       0.0
# 1                  7084                    1952.0                       1.0
# 2                 13696                    2159.0                      40.0
# 3                  9814                    1123.0                      36.0
# 4                 16297                    1672.0                      78.0
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                     1.196197                      0.732293
# 1                     1.288208                      0.865021
# 2                     1.116869                      0.632134
# 3                     1.147676                      0.773804
# 4                     1.071092                      0.708822
#
#    Cells_AreaShape_EulerNumber  Cells_AreaShape_Extent  ...  \
# 0                          1.0                0.622053  ...
# 1                          1.0                0.572722  ...
# 2                          1.0                0.689766  ...
# 3                          1.0                0.702606  ...
# 4                          1.0                0.691606  ...
#
#    Image_Width_IllumAGP  Image_Width_IllumDNA  Image_Width_IllumER  \
# 0                  2160                  2160                 2160
# 1                  2160                  2160                 2160
# 2                  2160                  2160                 2160
# 3                  2160                  2160                 2160
# 4                  2160                  2160                 2160
#
#    Image_Width_IllumMito  Image_Width_IllumRNA  Image_Width_OrigAGP  \
# 0                   2160                  2160                 2160
# 1                   2160                  2160                 2160
# 2                   2160                  2160                 2160
# 3                   2160                  2160                 2160
# 4                   2160                  2160                 2160
#
#    Image_Width_OrigDNA  Image_Width_OrigER  Image_Width_OrigMito  \
# 0                 2160                2160                  2160
# 1                 2160                2160                  2160
# 2                 2160                2160                  2160
# 3                 2160                2160                  2160
# 4                 2160                2160                  2160
#
#    Image_Width_OrigRNA
# 0                 2160
# 1                 2160
# 2                 2160
# 3                 2160
# 4                 2160
#
# [5 rows x 2442 columns]

# %% [markdown]
# ## Save selected DataFrame to csv

# %%
import pickle
df_p_s0.to_csv("SQ00015195_raw.csv")
